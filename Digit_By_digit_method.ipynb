# %% [markdown]
# <a href="https://colab.research.google.com/github/Geek-ubaid/Deep-OCR/blob/master/Digit_By_digit_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Digit-by-digit method using MNIST Model

# %%
import cv2
import os
import pandas as pd
import shutil

# %% [markdown]
# ### Generating Indiviual Digits from frames of console (Already Completed no need to run again)

# %%
class cutDigits:

    def __init__(self, image=None, src_file_name=None, dst_folder_name='Datasets_digits', last_digit=4, labels=None):
        
        if image is None :
            self.image = cv2.imread(src_file_name)
        else:
            self.image = image
        self.src_file_name = src_file_name
        self.dst_folder_name = dst_folder_name
        self.last_digit=last_digit
        self.labels = labels

        self.box_size = None
        self.boxes = []



    def get_bounding_box_dummy(self):
       
        self.boxes = []
        self.box_size = self.image.shape[1]/4

        for i in range(self.last_digit):
            inf = i * self.box_size
            sup = (i+1) * self.box_size
            self.boxes += [self.image[:, int(inf):int(sup)]]


    def save_to_folder(self) :
       
        if self.dst_folder_name is None :
            return

        for i in range(len(self.boxes)):
            if self.labels :
                box = self.boxes[i]
                label = self.labels[i]
                src_file_name = self.src_file_name.split('/')[-1].split('.')[0]
                dst_file_name = '/content/drive/My Drive/TARP PROJECT/Datasets_digits/%s/%s_%s.jpg' % (label, src_file_name, str(i))
                print(dst_file_name)
                cv2.imwrite(dst_file_name, box)
                
            else:
                pass

# %%
import pandas as pd
import os

root_dir = '/content/drive/My Drive/TARP PROJECT'

digits_path = os.path.join(root_dir,'Datasets_digits/')

if os.path.exists(digits_path):
    shutil.rmtree(digits_path)
    for i in range(0,11):
        os.makedirs(digits_path + f'/{i}')
else:
    for i in range(0,11):
        os.makedirs(digits_path + f'/{i}')

# TODO: check why they fail

fail = 0

df = []
# NB: These 3 datasets were made with Excel

suffix = ".csv"
csv_directory = os.path.join(root_dir,'Datasets/')
csv_files = [i for i in os.listdir(csv_directory) if i.endswith( suffix )]
df = []
for i in range(len(csv_files)):
    data = pd.read_csv(csv_directory +csv_files[i], sep=';', index_col = 0)
    df.append(data)
        
df = pd.concat(df, axis=0)
df = df.replace("X", 10)

df.to_csv('images_data.csv')

data_fram_dir = '/content/drive/My Drive/TARP PROJECT/Datasets_frames'

for i in range(df.shape[0]):
    line = df.iloc[i]
    labels = [line.cadran_1, line.cadran_2, line.cadran_3, line.cadran_4]
    file_name = line.image
    src_file_name = data_fram_dir + f"/{file_name}"

    try :
        cutter = cutDigits(src_file_name=src_file_name, labels=labels)
        cutter.get_bounding_box_dummy()
        cutter.save_to_folder()

    except :
        fail += 1

print(fail)
# Out:
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/e104664ba1792dde641d87cd5d95f1df06786140_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/e104664ba1792dde641d87cd5d95f1df06786140_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/e104664ba1792dde641d87cd5d95f1df06786140_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/e104664ba1792dde641d87cd5d95f1df06786140_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/48990b5cbe173868040bd33f06fb1b80c2b4f28a_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/48990b5cbe173868040bd33f06fb1b80c2b4f28a_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/48990b5cbe173868040bd33f06fb1b80c2b4f28a_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/48990b5cbe173868040bd33f06fb1b80c2b4f28a_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/9e111802446b62b86aeffe911415ad28227caba7_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/9e111802446b62b86aeffe911415ad28227caba7_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/9e111802446b62b86aeffe911415ad28227caba7_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/9e111802446b62b86aeffe911415ad28227caba7_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/f78fe5a461f28bc770a7dd856878bb4a314a9027_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/f78fe5a461f28bc770a7dd856878bb4a314a9027_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/f78fe5a461f28bc770a7dd856878bb4a314a9027_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/f78fe5a461f28bc770a7dd856878bb4a314a9027_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/c836ea17748e562c99f93edc51f2b900664ec37d_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/c836ea17748e562c99f93edc51f2b900664ec37d_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/c836ea17748e562c99f93edc51f2b900664ec37d_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/c836ea17748e562c99f93edc51f2b900664ec37d_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/ad09efeb3fb287283c6674797b9214313d12b5f1_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/ad09efeb3fb287283c6674797b9214313d12b5f1_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/ad09efeb3fb287283c6674797b9214313d12b5f1_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/ad09efeb3fb287283c6674797b9214313d12b5f1_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/87e827d58b36c7921568b270eae938e677c97207_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/87e827d58b36c7921568b270eae938e677c97207_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/87e827d58b36c7921568b270eae938e677c97207_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/87e827d58b36c7921568b270eae938e677c97207_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/fdddffcd1423ea0366eb81802ce1351bccf6dcaa_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/fdddffcd1423ea0366eb81802ce1351bccf6dcaa_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/fdddffcd1423ea0366eb81802ce1351bccf6dcaa_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/fdddffcd1423ea0366eb81802ce1351bccf6dcaa_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/2b6481132ed176928dfeefd11f7b10b56b49d517_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/2b6481132ed176928dfeefd11f7b10b56b49d517_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/2b6481132ed176928dfeefd11f7b10b56b49d517_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/2b6481132ed176928dfeefd11f7b10b56b49d517_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/fbd02b4f1eac089a9af1a9e0a24e888e3226d6bc_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/fbd02b4f1eac089a9af1a9e0a24e888e3226d6bc_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/fbd02b4f1eac089a9af1a9e0a24e888e3226d6bc_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/fbd02b4f1eac089a9af1a9e0a24e888e3226d6bc_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/caf2e1f69e943deb7a05a4b1f08de37651b9498b_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/caf2e1f69e943deb7a05a4b1f08de37651b9498b_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/caf2e1f69e943deb7a05a4b1f08de37651b9498b_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/caf2e1f69e943deb7a05a4b1f08de37651b9498b_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/f9b1f447c64e60597eef190ab328460c77a17bd0_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/f9b1f447c64e60597eef190ab328460c77a17bd0_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/f9b1f447c64e60597eef190ab328460c77a17bd0_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/f9b1f447c64e60597eef190ab328460c77a17bd0_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/2c07716d1d18e0d407cb113745689d5f9d45f307_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/2c07716d1d18e0d407cb113745689d5f9d45f307_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/2c07716d1d18e0d407cb113745689d5f9d45f307_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/2c07716d1d18e0d407cb113745689d5f9d45f307_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/afc914e1bdf29f16b78de8afd3dd3739a55dc914_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/afc914e1bdf29f16b78de8afd3dd3739a55dc914_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/afc914e1bdf29f16b78de8afd3dd3739a55dc914_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/afc914e1bdf29f16b78de8afd3dd3739a55dc914_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/ffd083a696ac010ca5a9a3cbecdb28a57a167732_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/ffd083a696ac010ca5a9a3cbecdb28a57a167732_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/ffd083a696ac010ca5a9a3cbecdb28a57a167732_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/ffd083a696ac010ca5a9a3cbecdb28a57a167732_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/aee88596159ace71523271065199866d5ed89dad_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/aee88596159ace71523271065199866d5ed89dad_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/aee88596159ace71523271065199866d5ed89dad_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/aee88596159ace71523271065199866d5ed89dad_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/64497aa7f4d0ec03260d50917487bf7e0dad8631_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/64497aa7f4d0ec03260d50917487bf7e0dad8631_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/64497aa7f4d0ec03260d50917487bf7e0dad8631_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/64497aa7f4d0ec03260d50917487bf7e0dad8631_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/34bd9ee3b020d9cd5297d6990784719bc68f2f2e_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/34bd9ee3b020d9cd5297d6990784719bc68f2f2e_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/34bd9ee3b020d9cd5297d6990784719bc68f2f2e_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/34bd9ee3b020d9cd5297d6990784719bc68f2f2e_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/c1db6c89fb26a051f71726f7df032e43de6046bc_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/c1db6c89fb26a051f71726f7df032e43de6046bc_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/c1db6c89fb26a051f71726f7df032e43de6046bc_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/c1db6c89fb26a051f71726f7df032e43de6046bc_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/c1119af716de4f4954efb087092a49ee3b48be13_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/c1119af716de4f4954efb087092a49ee3b48be13_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/c1119af716de4f4954efb087092a49ee3b48be13_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/c1119af716de4f4954efb087092a49ee3b48be13_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/51bf596a3c477f7944dd6d1fa83da310da375dc0_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/51bf596a3c477f7944dd6d1fa83da310da375dc0_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/51bf596a3c477f7944dd6d1fa83da310da375dc0_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/51bf596a3c477f7944dd6d1fa83da310da375dc0_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/165679858cfc4cd754e71a14d0381bc94a521cba_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/165679858cfc4cd754e71a14d0381bc94a521cba_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/165679858cfc4cd754e71a14d0381bc94a521cba_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/165679858cfc4cd754e71a14d0381bc94a521cba_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/26f0a94f2cb7b8637e3f5339799d5f4ba1029024_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/26f0a94f2cb7b8637e3f5339799d5f4ba1029024_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/26f0a94f2cb7b8637e3f5339799d5f4ba1029024_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/26f0a94f2cb7b8637e3f5339799d5f4ba1029024_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/852980ab54fe5cf1039940b0e6ac33a47172a12f_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/852980ab54fe5cf1039940b0e6ac33a47172a12f_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/852980ab54fe5cf1039940b0e6ac33a47172a12f_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/852980ab54fe5cf1039940b0e6ac33a47172a12f_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/9f7011199d11492f06dd62fc02845952175a8741_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/9f7011199d11492f06dd62fc02845952175a8741_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/9f7011199d11492f06dd62fc02845952175a8741_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/9f7011199d11492f06dd62fc02845952175a8741_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/3c823ec6e7a7405211c7d9281432a406929eff97_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/3c823ec6e7a7405211c7d9281432a406929eff97_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/3c823ec6e7a7405211c7d9281432a406929eff97_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/3c823ec6e7a7405211c7d9281432a406929eff97_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/d795e6592de9c1c5187a86769b8c5d7444cbaefd_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/d795e6592de9c1c5187a86769b8c5d7444cbaefd_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/d795e6592de9c1c5187a86769b8c5d7444cbaefd_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/d795e6592de9c1c5187a86769b8c5d7444cbaefd_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/5efa991cf18e861feaedf77355a6de1a010cb79b_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/5efa991cf18e861feaedf77355a6de1a010cb79b_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/5efa991cf18e861feaedf77355a6de1a010cb79b_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/5efa991cf18e861feaedf77355a6de1a010cb79b_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/caed5ebb6fc271d447c2f286dab64583e64c3324_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/caed5ebb6fc271d447c2f286dab64583e64c3324_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/caed5ebb6fc271d447c2f286dab64583e64c3324_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/caed5ebb6fc271d447c2f286dab64583e64c3324_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0a07d2cff5beb0580bca191427e8cd6e1a0eb678_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/0a07d2cff5beb0580bca191427e8cd6e1a0eb678_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/0a07d2cff5beb0580bca191427e8cd6e1a0eb678_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/0a07d2cff5beb0580bca191427e8cd6e1a0eb678_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/45d7f253212cb2fbb401aa6193d8b8e4e4420854_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/45d7f253212cb2fbb401aa6193d8b8e4e4420854_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/45d7f253212cb2fbb401aa6193d8b8e4e4420854_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/45d7f253212cb2fbb401aa6193d8b8e4e4420854_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/b9459761282e4785af2ece0ad86a9fcd05047bfd_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/b9459761282e4785af2ece0ad86a9fcd05047bfd_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/b9459761282e4785af2ece0ad86a9fcd05047bfd_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/b9459761282e4785af2ece0ad86a9fcd05047bfd_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/04dc6be4599a36518fcb26bf9355508d57ce6887_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/04dc6be4599a36518fcb26bf9355508d57ce6887_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/04dc6be4599a36518fcb26bf9355508d57ce6887_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/04dc6be4599a36518fcb26bf9355508d57ce6887_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/e6bf1df203b043c813d09f9db881595406920725_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/e6bf1df203b043c813d09f9db881595406920725_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/e6bf1df203b043c813d09f9db881595406920725_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/e6bf1df203b043c813d09f9db881595406920725_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/e47f55e29fb263bcdda378a8fc9fcc14cb532653_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/e47f55e29fb263bcdda378a8fc9fcc14cb532653_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/e47f55e29fb263bcdda378a8fc9fcc14cb532653_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/e47f55e29fb263bcdda378a8fc9fcc14cb532653_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/16059ed087ceb8a0d664934a78c414349bf9ac93_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/16059ed087ceb8a0d664934a78c414349bf9ac93_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/16059ed087ceb8a0d664934a78c414349bf9ac93_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/16059ed087ceb8a0d664934a78c414349bf9ac93_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/86aefd62c2e164037a5fdfa2feda74801a5da14c_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/86aefd62c2e164037a5fdfa2feda74801a5da14c_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/86aefd62c2e164037a5fdfa2feda74801a5da14c_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/86aefd62c2e164037a5fdfa2feda74801a5da14c_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/ae7c13f09ce55a6ebb4eab0819b5340f960e89f1_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/ae7c13f09ce55a6ebb4eab0819b5340f960e89f1_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/ae7c13f09ce55a6ebb4eab0819b5340f960e89f1_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/ae7c13f09ce55a6ebb4eab0819b5340f960e89f1_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/a7587241454eeec7fa380250102423a7ff64c22b_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/a7587241454eeec7fa380250102423a7ff64c22b_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/a7587241454eeec7fa380250102423a7ff64c22b_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/a7587241454eeec7fa380250102423a7ff64c22b_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/647517ae17cb333fe4187bdaec6db1e919c52896_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/647517ae17cb333fe4187bdaec6db1e919c52896_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/647517ae17cb333fe4187bdaec6db1e919c52896_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/647517ae17cb333fe4187bdaec6db1e919c52896_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/6e698f0b367607f0fa89763a2f1c3e11c42096ad_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/6e698f0b367607f0fa89763a2f1c3e11c42096ad_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/6e698f0b367607f0fa89763a2f1c3e11c42096ad_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/6e698f0b367607f0fa89763a2f1c3e11c42096ad_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/7df49abdbd72e550b6f37ebb5206ab4e94f4be7d_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/7df49abdbd72e550b6f37ebb5206ab4e94f4be7d_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/7df49abdbd72e550b6f37ebb5206ab4e94f4be7d_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/7df49abdbd72e550b6f37ebb5206ab4e94f4be7d_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/58b18aba0f01c20bc6042525158579785c74eba0_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/58b18aba0f01c20bc6042525158579785c74eba0_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/58b18aba0f01c20bc6042525158579785c74eba0_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/58b18aba0f01c20bc6042525158579785c74eba0_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/fc302f8fddf7e0a77550953f36d6a5148019680e_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/fc302f8fddf7e0a77550953f36d6a5148019680e_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/fc302f8fddf7e0a77550953f36d6a5148019680e_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/fc302f8fddf7e0a77550953f36d6a5148019680e_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/6d9e01bb68c31e9227beb6b0fd52423f21c16648_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/6d9e01bb68c31e9227beb6b0fd52423f21c16648_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/6d9e01bb68c31e9227beb6b0fd52423f21c16648_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/6d9e01bb68c31e9227beb6b0fd52423f21c16648_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1bc7bbefa14f6d7680e055191f8ba99823defba6_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1bc7bbefa14f6d7680e055191f8ba99823defba6_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/1bc7bbefa14f6d7680e055191f8ba99823defba6_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/1bc7bbefa14f6d7680e055191f8ba99823defba6_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/98ec95acaf26bde374a5301009c0fe7c09e447ac_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/98ec95acaf26bde374a5301009c0fe7c09e447ac_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/98ec95acaf26bde374a5301009c0fe7c09e447ac_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/98ec95acaf26bde374a5301009c0fe7c09e447ac_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/184bad9043c572a63c3e2f838e79955faf946181_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/184bad9043c572a63c3e2f838e79955faf946181_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/184bad9043c572a63c3e2f838e79955faf946181_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/184bad9043c572a63c3e2f838e79955faf946181_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/b2b721636f4ba3ef7cd4f2e2eec3730116470f58_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/b2b721636f4ba3ef7cd4f2e2eec3730116470f58_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/b2b721636f4ba3ef7cd4f2e2eec3730116470f58_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/b2b721636f4ba3ef7cd4f2e2eec3730116470f58_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/2f4e7043428941035e5fec2ae92e9b6b6b14ddd7_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/2f4e7043428941035e5fec2ae92e9b6b6b14ddd7_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/2f4e7043428941035e5fec2ae92e9b6b6b14ddd7_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/2f4e7043428941035e5fec2ae92e9b6b6b14ddd7_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/4ac652ff81459defe503fb6a28feaedf4ac2fb7c_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/4ac652ff81459defe503fb6a28feaedf4ac2fb7c_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/4ac652ff81459defe503fb6a28feaedf4ac2fb7c_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/4ac652ff81459defe503fb6a28feaedf4ac2fb7c_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/28664c8bffb7bec48411563f3c0db7e5f118889b_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/28664c8bffb7bec48411563f3c0db7e5f118889b_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/28664c8bffb7bec48411563f3c0db7e5f118889b_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/28664c8bffb7bec48411563f3c0db7e5f118889b_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/bf81cd3258241d91ba9e915e8bf309da16a574ed_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/bf81cd3258241d91ba9e915e8bf309da16a574ed_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/bf81cd3258241d91ba9e915e8bf309da16a574ed_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/bf81cd3258241d91ba9e915e8bf309da16a574ed_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/41ba9d95ab7ef9a43bfccfa13f9ffc160f25b8ab_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/41ba9d95ab7ef9a43bfccfa13f9ffc160f25b8ab_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/41ba9d95ab7ef9a43bfccfa13f9ffc160f25b8ab_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/41ba9d95ab7ef9a43bfccfa13f9ffc160f25b8ab_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/45fec9e34de2083d6e045b7ee99b0780183ab0e9_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/45fec9e34de2083d6e045b7ee99b0780183ab0e9_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/45fec9e34de2083d6e045b7ee99b0780183ab0e9_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/45fec9e34de2083d6e045b7ee99b0780183ab0e9_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/4534e267bea350e8afdfff3e9c4d0933933b0429_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/4534e267bea350e8afdfff3e9c4d0933933b0429_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/4534e267bea350e8afdfff3e9c4d0933933b0429_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/4534e267bea350e8afdfff3e9c4d0933933b0429_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/b746312f413f1373779b00b82d9c83c0e3d881b2_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/b746312f413f1373779b00b82d9c83c0e3d881b2_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/b746312f413f1373779b00b82d9c83c0e3d881b2_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/b746312f413f1373779b00b82d9c83c0e3d881b2_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/474494db28922d7e400d7b24541695bcb6366532_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/474494db28922d7e400d7b24541695bcb6366532_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/474494db28922d7e400d7b24541695bcb6366532_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/474494db28922d7e400d7b24541695bcb6366532_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/fe1dc0a44b58c36fd9215a6d201920deefe7c309_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/fe1dc0a44b58c36fd9215a6d201920deefe7c309_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/fe1dc0a44b58c36fd9215a6d201920deefe7c309_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/fe1dc0a44b58c36fd9215a6d201920deefe7c309_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/dd31a247c313689d77bbf8fbf2bd7dbac8d44333_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/dd31a247c313689d77bbf8fbf2bd7dbac8d44333_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/dd31a247c313689d77bbf8fbf2bd7dbac8d44333_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/dd31a247c313689d77bbf8fbf2bd7dbac8d44333_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/8ecb0b9d2fba086caf434b7a4864434f9ea0da0e_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/8ecb0b9d2fba086caf434b7a4864434f9ea0da0e_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/8ecb0b9d2fba086caf434b7a4864434f9ea0da0e_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/8ecb0b9d2fba086caf434b7a4864434f9ea0da0e_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/b772d011f189cc97e88de5d114a0821941435fd4_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/b772d011f189cc97e88de5d114a0821941435fd4_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/b772d011f189cc97e88de5d114a0821941435fd4_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/b772d011f189cc97e88de5d114a0821941435fd4_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/631887ed74c7390a6e2c81d5c11ac529b40cac24_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/631887ed74c7390a6e2c81d5c11ac529b40cac24_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/631887ed74c7390a6e2c81d5c11ac529b40cac24_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/631887ed74c7390a6e2c81d5c11ac529b40cac24_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/bf52fb9d9ca985341979a2b9db06838614f306b5_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/bf52fb9d9ca985341979a2b9db06838614f306b5_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/bf52fb9d9ca985341979a2b9db06838614f306b5_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/bf52fb9d9ca985341979a2b9db06838614f306b5_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0c1979be441eb95a6f1c7aaba65edeefda5412a9_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0c1979be441eb95a6f1c7aaba65edeefda5412a9_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/0c1979be441eb95a6f1c7aaba65edeefda5412a9_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/0c1979be441eb95a6f1c7aaba65edeefda5412a9_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/129bb38115a3cf224bdf9a593e2df0465db79bc6_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/129bb38115a3cf224bdf9a593e2df0465db79bc6_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/129bb38115a3cf224bdf9a593e2df0465db79bc6_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/129bb38115a3cf224bdf9a593e2df0465db79bc6_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/659667ef81a9faea100e326ae165535e530785d4_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/659667ef81a9faea100e326ae165535e530785d4_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/659667ef81a9faea100e326ae165535e530785d4_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/659667ef81a9faea100e326ae165535e530785d4_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0688de8a02d78ef6fc31ee7aa625eb1a7dc3ba4a_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/0688de8a02d78ef6fc31ee7aa625eb1a7dc3ba4a_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/0688de8a02d78ef6fc31ee7aa625eb1a7dc3ba4a_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/0688de8a02d78ef6fc31ee7aa625eb1a7dc3ba4a_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/e452881a7b82c7b224e38b754424da1f3b96060d_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/e452881a7b82c7b224e38b754424da1f3b96060d_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/e452881a7b82c7b224e38b754424da1f3b96060d_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/e452881a7b82c7b224e38b754424da1f3b96060d_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/57f163278000a53c4199e6cff9e949bef60154f7_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/57f163278000a53c4199e6cff9e949bef60154f7_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/57f163278000a53c4199e6cff9e949bef60154f7_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/57f163278000a53c4199e6cff9e949bef60154f7_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/ad303bb8b900d6002a618c9edb2691e4927986d8_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/ad303bb8b900d6002a618c9edb2691e4927986d8_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/ad303bb8b900d6002a618c9edb2691e4927986d8_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/ad303bb8b900d6002a618c9edb2691e4927986d8_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/cc3f2c7a152b1353e4d0149ea4516bed71c781df_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/cc3f2c7a152b1353e4d0149ea4516bed71c781df_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/cc3f2c7a152b1353e4d0149ea4516bed71c781df_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/cc3f2c7a152b1353e4d0149ea4516bed71c781df_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/ebbeb1b4a007e7d5a4f62c2b504484c09fb43dde_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/ebbeb1b4a007e7d5a4f62c2b504484c09fb43dde_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/ebbeb1b4a007e7d5a4f62c2b504484c09fb43dde_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/ebbeb1b4a007e7d5a4f62c2b504484c09fb43dde_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/b77a9c3bdaf91f0fcce9ca05f598c34139a11205_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/b77a9c3bdaf91f0fcce9ca05f598c34139a11205_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/b77a9c3bdaf91f0fcce9ca05f598c34139a11205_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/b77a9c3bdaf91f0fcce9ca05f598c34139a11205_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/80f4419eee02f02c34f4b4f65d65b34ad07be278_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/80f4419eee02f02c34f4b4f65d65b34ad07be278_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/80f4419eee02f02c34f4b4f65d65b34ad07be278_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/80f4419eee02f02c34f4b4f65d65b34ad07be278_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/f467271c3de398ffe78268830059c2fd8dc29b90_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/f467271c3de398ffe78268830059c2fd8dc29b90_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/f467271c3de398ffe78268830059c2fd8dc29b90_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/f467271c3de398ffe78268830059c2fd8dc29b90_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/ea505d33dc581c054d6ab218048536b9e5b05fe4_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/ea505d33dc581c054d6ab218048536b9e5b05fe4_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/ea505d33dc581c054d6ab218048536b9e5b05fe4_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/ea505d33dc581c054d6ab218048536b9e5b05fe4_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0fc1317374529ccc9ead94895c8722c1681ce187_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0fc1317374529ccc9ead94895c8722c1681ce187_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/0fc1317374529ccc9ead94895c8722c1681ce187_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/0fc1317374529ccc9ead94895c8722c1681ce187_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/97fbf9288a53ee809eb4538b507b1b8c01b17be5_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/97fbf9288a53ee809eb4538b507b1b8c01b17be5_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/97fbf9288a53ee809eb4538b507b1b8c01b17be5_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/97fbf9288a53ee809eb4538b507b1b8c01b17be5_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/f1cbc378299894f7f09e6d3aea25b0f962e9af8a_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/f1cbc378299894f7f09e6d3aea25b0f962e9af8a_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/f1cbc378299894f7f09e6d3aea25b0f962e9af8a_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/f1cbc378299894f7f09e6d3aea25b0f962e9af8a_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/10edfb73d2b261b00e2f509ec36b05c4d6fab706_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/10edfb73d2b261b00e2f509ec36b05c4d6fab706_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/10edfb73d2b261b00e2f509ec36b05c4d6fab706_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/10edfb73d2b261b00e2f509ec36b05c4d6fab706_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/9fbf5baf2483b1c0cb21c8d00cbe6dac038b2ff1_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/9fbf5baf2483b1c0cb21c8d00cbe6dac038b2ff1_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/9fbf5baf2483b1c0cb21c8d00cbe6dac038b2ff1_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/9fbf5baf2483b1c0cb21c8d00cbe6dac038b2ff1_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/9254cdb3e6d79badf7aeed6973383edaaaaa7e64_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/9254cdb3e6d79badf7aeed6973383edaaaaa7e64_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/9254cdb3e6d79badf7aeed6973383edaaaaa7e64_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/9254cdb3e6d79badf7aeed6973383edaaaaa7e64_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/fc7e8efc0039ff4f010ef9b28783351575e225bd_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/fc7e8efc0039ff4f010ef9b28783351575e225bd_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/fc7e8efc0039ff4f010ef9b28783351575e225bd_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/fc7e8efc0039ff4f010ef9b28783351575e225bd_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/840502a0ad0ee55ef41b7a051cc86d9471559cb1_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/840502a0ad0ee55ef41b7a051cc86d9471559cb1_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/840502a0ad0ee55ef41b7a051cc86d9471559cb1_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/840502a0ad0ee55ef41b7a051cc86d9471559cb1_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0086c28630535f9d722eed740f9ce3f8336ec432_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/0086c28630535f9d722eed740f9ce3f8336ec432_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/0086c28630535f9d722eed740f9ce3f8336ec432_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/0086c28630535f9d722eed740f9ce3f8336ec432_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/b1195235570b5ee9f11ba8adb64e165b8d81e6d0_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/b1195235570b5ee9f11ba8adb64e165b8d81e6d0_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/b1195235570b5ee9f11ba8adb64e165b8d81e6d0_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/b1195235570b5ee9f11ba8adb64e165b8d81e6d0_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/e72a9402841f1fd6a2c3c9f27a25d405640ce194_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/e72a9402841f1fd6a2c3c9f27a25d405640ce194_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/e72a9402841f1fd6a2c3c9f27a25d405640ce194_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/e72a9402841f1fd6a2c3c9f27a25d405640ce194_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/18a1f78397b98a02bcbfbe69b390b9c72be1d686_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/18a1f78397b98a02bcbfbe69b390b9c72be1d686_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/18a1f78397b98a02bcbfbe69b390b9c72be1d686_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/18a1f78397b98a02bcbfbe69b390b9c72be1d686_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/6b5d829c02194467ae05ab5c9cc563671814c159_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/6b5d829c02194467ae05ab5c9cc563671814c159_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/6b5d829c02194467ae05ab5c9cc563671814c159_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/6b5d829c02194467ae05ab5c9cc563671814c159_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/60a6920c0470dee667dd218bab542e0528e3ba8f_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/60a6920c0470dee667dd218bab542e0528e3ba8f_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/60a6920c0470dee667dd218bab542e0528e3ba8f_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/60a6920c0470dee667dd218bab542e0528e3ba8f_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/a3169ca6db33dda2b32c96f5063117e2ee3eb2c0_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/a3169ca6db33dda2b32c96f5063117e2ee3eb2c0_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/a3169ca6db33dda2b32c96f5063117e2ee3eb2c0_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/a3169ca6db33dda2b32c96f5063117e2ee3eb2c0_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/bf587a4df84cc4dd291e9c64b1c0e5a0d198580c_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/bf587a4df84cc4dd291e9c64b1c0e5a0d198580c_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/bf587a4df84cc4dd291e9c64b1c0e5a0d198580c_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/bf587a4df84cc4dd291e9c64b1c0e5a0d198580c_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/2236648840225d976d1feb6155c9de07b129f403_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/2236648840225d976d1feb6155c9de07b129f403_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/2236648840225d976d1feb6155c9de07b129f403_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/2236648840225d976d1feb6155c9de07b129f403_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/60f603ee8cc95cf1125c4f159502f65b85195bef_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/60f603ee8cc95cf1125c4f159502f65b85195bef_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/60f603ee8cc95cf1125c4f159502f65b85195bef_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/60f603ee8cc95cf1125c4f159502f65b85195bef_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/36a73c74ef0b76639e12488651f587fb06a9baab_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/36a73c74ef0b76639e12488651f587fb06a9baab_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/36a73c74ef0b76639e12488651f587fb06a9baab_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/36a73c74ef0b76639e12488651f587fb06a9baab_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/957d8fe28fed4ca5f8b2aab0a4ff3032ca631165_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/957d8fe28fed4ca5f8b2aab0a4ff3032ca631165_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/957d8fe28fed4ca5f8b2aab0a4ff3032ca631165_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/957d8fe28fed4ca5f8b2aab0a4ff3032ca631165_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/768ffa2daba12461bc698a2b740ecbbfb15fce8c_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/768ffa2daba12461bc698a2b740ecbbfb15fce8c_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/768ffa2daba12461bc698a2b740ecbbfb15fce8c_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/768ffa2daba12461bc698a2b740ecbbfb15fce8c_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/b7f78a8f28674b7700c7c8f0c1e949cd6eab5f42_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/b7f78a8f28674b7700c7c8f0c1e949cd6eab5f42_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/b7f78a8f28674b7700c7c8f0c1e949cd6eab5f42_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/b7f78a8f28674b7700c7c8f0c1e949cd6eab5f42_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/a6bd371130fec0f12d7b2a32865ddae3e026aa37_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/a6bd371130fec0f12d7b2a32865ddae3e026aa37_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/a6bd371130fec0f12d7b2a32865ddae3e026aa37_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/a6bd371130fec0f12d7b2a32865ddae3e026aa37_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/fbb22d2e929fc4e7cef446edf6306fd807329bea_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/fbb22d2e929fc4e7cef446edf6306fd807329bea_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/fbb22d2e929fc4e7cef446edf6306fd807329bea_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/fbb22d2e929fc4e7cef446edf6306fd807329bea_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/aaa54960feb69aa9be5bb088ad9dbf0a6d4cee2d_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/aaa54960feb69aa9be5bb088ad9dbf0a6d4cee2d_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/aaa54960feb69aa9be5bb088ad9dbf0a6d4cee2d_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/aaa54960feb69aa9be5bb088ad9dbf0a6d4cee2d_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/c0313de737369b43bb8d6855517e4980630c89bd_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/c0313de737369b43bb8d6855517e4980630c89bd_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/c0313de737369b43bb8d6855517e4980630c89bd_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/c0313de737369b43bb8d6855517e4980630c89bd_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/41b5d9fc07d41287a37339282057a1aff4c7b2ed_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/41b5d9fc07d41287a37339282057a1aff4c7b2ed_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/41b5d9fc07d41287a37339282057a1aff4c7b2ed_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/41b5d9fc07d41287a37339282057a1aff4c7b2ed_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/846136278e66e5431f21403ca750168fd825930a_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/846136278e66e5431f21403ca750168fd825930a_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/846136278e66e5431f21403ca750168fd825930a_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/846136278e66e5431f21403ca750168fd825930a_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/85734ff0041e6244f29ffcfbe2c89d8c580162dc_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/85734ff0041e6244f29ffcfbe2c89d8c580162dc_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/85734ff0041e6244f29ffcfbe2c89d8c580162dc_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/85734ff0041e6244f29ffcfbe2c89d8c580162dc_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/02b292a500dfb9192379fe830534cfd8b38f003f_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/02b292a500dfb9192379fe830534cfd8b38f003f_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/02b292a500dfb9192379fe830534cfd8b38f003f_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/02b292a500dfb9192379fe830534cfd8b38f003f_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/7c78f916fc9f716f6c7db5095cd690f79b29cd31_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/7c78f916fc9f716f6c7db5095cd690f79b29cd31_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/7c78f916fc9f716f6c7db5095cd690f79b29cd31_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/7c78f916fc9f716f6c7db5095cd690f79b29cd31_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/2bf3406560e9dc92dbcb5b50291689e7ff858a80_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/2bf3406560e9dc92dbcb5b50291689e7ff858a80_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/2bf3406560e9dc92dbcb5b50291689e7ff858a80_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/2bf3406560e9dc92dbcb5b50291689e7ff858a80_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/f459be06cce486e8199930cfb3ed8c42d2f1a4b8_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/f459be06cce486e8199930cfb3ed8c42d2f1a4b8_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/f459be06cce486e8199930cfb3ed8c42d2f1a4b8_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/f459be06cce486e8199930cfb3ed8c42d2f1a4b8_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/7910fdcf50e2e8a471e13056eec64befa8a94140_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/7910fdcf50e2e8a471e13056eec64befa8a94140_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/7910fdcf50e2e8a471e13056eec64befa8a94140_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/7910fdcf50e2e8a471e13056eec64befa8a94140_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/18f0202e901fb1ed202bc75d68533358e3c8b7e3_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/18f0202e901fb1ed202bc75d68533358e3c8b7e3_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/18f0202e901fb1ed202bc75d68533358e3c8b7e3_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/18f0202e901fb1ed202bc75d68533358e3c8b7e3_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/63a8e6111690bca37052c237047fd85162facf5d_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/63a8e6111690bca37052c237047fd85162facf5d_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/63a8e6111690bca37052c237047fd85162facf5d_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/63a8e6111690bca37052c237047fd85162facf5d_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/81ac47bdd1e225569ed626a723644a00216d8f75_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/81ac47bdd1e225569ed626a723644a00216d8f75_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/81ac47bdd1e225569ed626a723644a00216d8f75_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/81ac47bdd1e225569ed626a723644a00216d8f75_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1f1ec8eee75d4988d7756895aa780a6dee908118_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/1f1ec8eee75d4988d7756895aa780a6dee908118_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/1f1ec8eee75d4988d7756895aa780a6dee908118_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/1f1ec8eee75d4988d7756895aa780a6dee908118_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/8eeaee0a4748acb92d5fbbccd10c93d120b96986_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/8eeaee0a4748acb92d5fbbccd10c93d120b96986_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/8eeaee0a4748acb92d5fbbccd10c93d120b96986_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/8eeaee0a4748acb92d5fbbccd10c93d120b96986_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/cc4bf7bc265a045746f6a2ac3c77c6a498712307_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/cc4bf7bc265a045746f6a2ac3c77c6a498712307_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/cc4bf7bc265a045746f6a2ac3c77c6a498712307_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/cc4bf7bc265a045746f6a2ac3c77c6a498712307_3.jpg
# ...
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1b893ca373e455ecd830f74ddd3ca73153e9c5b3_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1b893ca373e455ecd830f74ddd3ca73153e9c5b3_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/1b893ca373e455ecd830f74ddd3ca73153e9c5b3_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/1b893ca373e455ecd830f74ddd3ca73153e9c5b3_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/07ffaa969b84410f21874827382a621d14b9449e_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/07ffaa969b84410f21874827382a621d14b9449e_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/07ffaa969b84410f21874827382a621d14b9449e_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/07ffaa969b84410f21874827382a621d14b9449e_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1c797fe75336bd3bb964aaa0478eae6c6592ba4a_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1c797fe75336bd3bb964aaa0478eae6c6592ba4a_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/1c797fe75336bd3bb964aaa0478eae6c6592ba4a_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/1c797fe75336bd3bb964aaa0478eae6c6592ba4a_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1a186e466f9a4489ab87293a27d4dcd11f03ae6a_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1a186e466f9a4489ab87293a27d4dcd11f03ae6a_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/1a186e466f9a4489ab87293a27d4dcd11f03ae6a_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/1a186e466f9a4489ab87293a27d4dcd11f03ae6a_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/14a12c1a3777e06c5438000d0b8cbe9d3a63f8ff_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/14a12c1a3777e06c5438000d0b8cbe9d3a63f8ff_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/14a12c1a3777e06c5438000d0b8cbe9d3a63f8ff_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/14a12c1a3777e06c5438000d0b8cbe9d3a63f8ff_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/233849d313f9989bc62ccc43a0d0fb0707a82550_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/233849d313f9989bc62ccc43a0d0fb0707a82550_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/233849d313f9989bc62ccc43a0d0fb0707a82550_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/233849d313f9989bc62ccc43a0d0fb0707a82550_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0778d3fc920676610e2f0504bc8777ed3283d116_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0778d3fc920676610e2f0504bc8777ed3283d116_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/0778d3fc920676610e2f0504bc8777ed3283d116_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/0778d3fc920676610e2f0504bc8777ed3283d116_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/04adebffeed113d944e9efcfe5503c3ba6bf467d_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/04adebffeed113d944e9efcfe5503c3ba6bf467d_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/04adebffeed113d944e9efcfe5503c3ba6bf467d_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/04adebffeed113d944e9efcfe5503c3ba6bf467d_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/192670613085adeceb2544472518d5dd9f4c9060_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/192670613085adeceb2544472518d5dd9f4c9060_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/192670613085adeceb2544472518d5dd9f4c9060_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/192670613085adeceb2544472518d5dd9f4c9060_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1abddd3978803e425609f69eba53c499a8d5c03c_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1abddd3978803e425609f69eba53c499a8d5c03c_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/1abddd3978803e425609f69eba53c499a8d5c03c_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/1abddd3978803e425609f69eba53c499a8d5c03c_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/10ece0d989c1d9630136066b3e7e682cabe9db36_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/10ece0d989c1d9630136066b3e7e682cabe9db36_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/10ece0d989c1d9630136066b3e7e682cabe9db36_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/10ece0d989c1d9630136066b3e7e682cabe9db36_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0a9323377845ae8b8f7c113f8c2d044c1c3bc8b3_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0a9323377845ae8b8f7c113f8c2d044c1c3bc8b3_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/0a9323377845ae8b8f7c113f8c2d044c1c3bc8b3_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/0a9323377845ae8b8f7c113f8c2d044c1c3bc8b3_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/05417700b76f523cc74f17d86d778a5273d99869_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/05417700b76f523cc74f17d86d778a5273d99869_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/05417700b76f523cc74f17d86d778a5273d99869_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/05417700b76f523cc74f17d86d778a5273d99869_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1206fa2db464244bc1fe8f5676afc879628d1ba4_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1206fa2db464244bc1fe8f5676afc879628d1ba4_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/1206fa2db464244bc1fe8f5676afc879628d1ba4_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/1206fa2db464244bc1fe8f5676afc879628d1ba4_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/2110c0be366f9cd65ee14af52adc4aa5c7c24f2d_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/2110c0be366f9cd65ee14af52adc4aa5c7c24f2d_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/2110c0be366f9cd65ee14af52adc4aa5c7c24f2d_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/2110c0be366f9cd65ee14af52adc4aa5c7c24f2d_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/222c634ae2ddf08431333ab0a6355b49bd2275dc_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/222c634ae2ddf08431333ab0a6355b49bd2275dc_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/222c634ae2ddf08431333ab0a6355b49bd2275dc_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/222c634ae2ddf08431333ab0a6355b49bd2275dc_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/02e3c045524b89495955874afae9f0832adac32c_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/02e3c045524b89495955874afae9f0832adac32c_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/02e3c045524b89495955874afae9f0832adac32c_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/02e3c045524b89495955874afae9f0832adac32c_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/00e22973fdbc19f1f703cdbd05a8606705bc60d1_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/00e22973fdbc19f1f703cdbd05a8606705bc60d1_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/00e22973fdbc19f1f703cdbd05a8606705bc60d1_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/00e22973fdbc19f1f703cdbd05a8606705bc60d1_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/06ad5ecd77f1eddc0dfc5fb98b089cdfee639319_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/06ad5ecd77f1eddc0dfc5fb98b089cdfee639319_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/06ad5ecd77f1eddc0dfc5fb98b089cdfee639319_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/06ad5ecd77f1eddc0dfc5fb98b089cdfee639319_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/20f21432f4534ab130c992704c273d9603b9872d_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/20f21432f4534ab130c992704c273d9603b9872d_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/20f21432f4534ab130c992704c273d9603b9872d_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/9/20f21432f4534ab130c992704c273d9603b9872d_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/00f35ec57ceabe2950b8b59077ca09667763c89a_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/00f35ec57ceabe2950b8b59077ca09667763c89a_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/00f35ec57ceabe2950b8b59077ca09667763c89a_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/00f35ec57ceabe2950b8b59077ca09667763c89a_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/118586203f37df4e8821d18c381c4995091f5530_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/118586203f37df4e8821d18c381c4995091f5530_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/118586203f37df4e8821d18c381c4995091f5530_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/118586203f37df4e8821d18c381c4995091f5530_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0aa6fa634d2cce0403e7bad211ba727aa026f37c_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/0aa6fa634d2cce0403e7bad211ba727aa026f37c_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/0aa6fa634d2cce0403e7bad211ba727aa026f37c_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/0aa6fa634d2cce0403e7bad211ba727aa026f37c_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/243eaca08f16e3785153d8efecd2f02a3e3cf50c_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/243eaca08f16e3785153d8efecd2f02a3e3cf50c_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/243eaca08f16e3785153d8efecd2f02a3e3cf50c_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/243eaca08f16e3785153d8efecd2f02a3e3cf50c_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0cc7d11bcd59ef42b4ad270f3db77b5c72f9f3c5_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0cc7d11bcd59ef42b4ad270f3db77b5c72f9f3c5_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/0cc7d11bcd59ef42b4ad270f3db77b5c72f9f3c5_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/0cc7d11bcd59ef42b4ad270f3db77b5c72f9f3c5_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/106410378c75699f5e9292dd8b87b22b8b57a9ec_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/106410378c75699f5e9292dd8b87b22b8b57a9ec_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/106410378c75699f5e9292dd8b87b22b8b57a9ec_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/106410378c75699f5e9292dd8b87b22b8b57a9ec_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0ecfcc5eb4b3cd52adf347bcb3fc2f31138b29aa_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0ecfcc5eb4b3cd52adf347bcb3fc2f31138b29aa_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/0ecfcc5eb4b3cd52adf347bcb3fc2f31138b29aa_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/0ecfcc5eb4b3cd52adf347bcb3fc2f31138b29aa_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1b6f4d87127bc721ac21921b0a8f6d6f29eb59cf_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/1b6f4d87127bc721ac21921b0a8f6d6f29eb59cf_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/1b6f4d87127bc721ac21921b0a8f6d6f29eb59cf_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/1b6f4d87127bc721ac21921b0a8f6d6f29eb59cf_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0578aa753099fe5c2525b14a9bacf995f9565f64_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0578aa753099fe5c2525b14a9bacf995f9565f64_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/0578aa753099fe5c2525b14a9bacf995f9565f64_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/0578aa753099fe5c2525b14a9bacf995f9565f64_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/02cb50cb6c7186ee1873765d14076e4a5c24ca7b_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/02cb50cb6c7186ee1873765d14076e4a5c24ca7b_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/02cb50cb6c7186ee1873765d14076e4a5c24ca7b_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/02cb50cb6c7186ee1873765d14076e4a5c24ca7b_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1dde96aa9f5ee70ec0a57fcfffadab3cd6421d1e_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/1dde96aa9f5ee70ec0a57fcfffadab3cd6421d1e_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/8/1dde96aa9f5ee70ec0a57fcfffadab3cd6421d1e_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/1dde96aa9f5ee70ec0a57fcfffadab3cd6421d1e_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/22c3865996ba4f1cb65fd06a185f204ee9f5bf27_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/22c3865996ba4f1cb65fd06a185f204ee9f5bf27_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/22c3865996ba4f1cb65fd06a185f204ee9f5bf27_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/22c3865996ba4f1cb65fd06a185f204ee9f5bf27_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0122de9a0c734ad199c00b352cc3b12729238b44_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0122de9a0c734ad199c00b352cc3b12729238b44_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/0122de9a0c734ad199c00b352cc3b12729238b44_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/0122de9a0c734ad199c00b352cc3b12729238b44_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1035422f1a10a2bdadf40f0eb0031927d1f101c8_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1035422f1a10a2bdadf40f0eb0031927d1f101c8_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/1035422f1a10a2bdadf40f0eb0031927d1f101c8_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/1035422f1a10a2bdadf40f0eb0031927d1f101c8_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/1ce0f4e786d44a3ce831e470c5bb9eac4602ad04_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/1ce0f4e786d44a3ce831e470c5bb9eac4602ad04_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/1ce0f4e786d44a3ce831e470c5bb9eac4602ad04_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/6/1ce0f4e786d44a3ce831e470c5bb9eac4602ad04_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/043af7a5763b15b7c281eea6de8474ea7133bc5d_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/1/043af7a5763b15b7c281eea6de8474ea7133bc5d_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/043af7a5763b15b7c281eea6de8474ea7133bc5d_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/4/043af7a5763b15b7c281eea6de8474ea7133bc5d_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0c2564bc75fc119ef34281405933d48d9db45ae5_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0c2564bc75fc119ef34281405933d48d9db45ae5_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/5/0c2564bc75fc119ef34281405933d48d9db45ae5_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/0c2564bc75fc119ef34281405933d48d9db45ae5_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/220fe475a2c39efdf7f716603e1b4f60ba10f672_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/220fe475a2c39efdf7f716603e1b4f60ba10f672_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/7/220fe475a2c39efdf7f716603e1b4f60ba10f672_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/0/220fe475a2c39efdf7f716603e1b4f60ba10f672_3.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0b7d7c92f3a0f9f466067984a57a494b01ee894f_0.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/10/0b7d7c92f3a0f9f466067984a57a494b01ee894f_1.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/3/0b7d7c92f3a0f9f466067984a57a494b01ee894f_2.jpg
# /content/drive/My Drive/TARP PROJECT/Datasets_digits/2/0b7d7c92f3a0f9f466067984a57a494b01ee894f_3.jpg
# 170

# %% [markdown]
# ## MNIST Handwritten Model Pretrained and Architecture (Run only when to retrain your model)

# %% [markdown]
# ### Importing Packages

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# %% [markdown]
# ### MNIST Model Architecture VGG16

# %%
batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 142s 2ms/step - loss: 0.2573 - accuracy: 0.9204 - val_loss: 0.0564 - val_accuracy: 0.9822
# Epoch 2/12
# 60000/60000 [==============================] - 142s 2ms/step - loss: 0.0851 - accuracy: 0.9747 - val_loss: 0.0371 - val_accuracy: 0.9881
# Epoch 3/12
# 60000/60000 [==============================] - 142s 2ms/step - loss: 0.0644 - accuracy: 0.9812 - val_loss: 0.0324 - val_accuracy: 0.9894
# Epoch 4/12
# 60000/60000 [==============================] - 142s 2ms/step - loss: 0.0537 - accuracy: 0.9837 - val_loss: 0.0301 - val_accuracy: 0.9893
# Epoch 5/12
# 60000/60000 [==============================] - 142s 2ms/step - loss: 0.0467 - accuracy: 0.9862 - val_loss: 0.0284 - val_accuracy: 0.9905
# Epoch 6/12
# 60000/60000 [==============================] - 142s 2ms/step - loss: 0.0397 - accuracy: 0.9879 - val_loss: 0.0303 - val_accuracy: 0.9903
# Epoch 7/12
# 60000/60000 [==============================] - 142s 2ms/step - loss: 0.0353 - accuracy: 0.9894 - val_loss: 0.0258 - val_accuracy: 0.9920
# Epoch 8/12
# 60000/60000 [==============================] - 142s 2ms/step - loss: 0.0321 - accuracy: 0.9901 - val_loss: 0.0256 - val_accuracy: 0.9920
# Epoch 9/12
# 60000/60000 [==============================] - 142s 2ms/step - loss: 0.0296 - accuracy: 0.9905 - val_loss: 0.0248 - val_accuracy: 0.9928
# Epoch 10/12
# 60000/60000 [==============================] - 142s 2ms/step - loss: 0.0284 - accuracy: 0.9912 - val_loss: 0.0277 - val_accuracy: 0.9914
# Epoch 11/12
# 60000/60000 [==============================] - 142s 2ms/step - loss: 0.0272 - accuracy: 0.9921 - val_loss: 0.0256 - val_accuracy: 0.9930
# Epoch 12/12
# 60000/60000 [==============================] - 141s 2ms/step - loss: 0.0247 - accuracy: 0.9921 - val_loss: 0.0269 - val_accuracy: 0.9913
# Test loss: 0.026861089086149512
# Test accuracy: 0.9912999868392944

# %% [markdown]
# ## Saving MNIST model for predictions (Save only when retrain the model)

# %%
model.save('mnist_digits.h5')

# %% [markdown]
# ### Using MNIST trained model on our digit images

# %%
from keras.models import load_model

model_path = '/content/drive/My Drive/TARP PROJECT/mnist_digits.h5'
model = load_model(model_path)

# %% [markdown]
# ### Test model on our custom digits generated from the meter display

# %%
import matplotlib.pyplot as plt
import numpy as np

def test_image(image_dir,image_name):
  img = cv2.imread(os.path.join(image_dir,image_name), 1)
  resized_image = cv2.resize(img,(28,28))

  print("Test Image-->")
  plt.imshow(resized_image)
  print(resized_image.shape)

  mg = cv2.cvtColor(resized_image,cv2.COLOR_BGR2GRAY)
  inverted_image = np.invert(mg)
  inverted_image = inverted_image/255
  inverted_image = inverted_image.astype('float64')

  plt.imshow(inverted_image)
  curr_shape = inverted_image.shape
  img_test = inverted_image.reshape((-1,curr_shape[0], curr_shape[1], 1))
  print("Final test image shape : ")
  print(img_test.shape)
  
  prediction = model.predict(img_test)
  return np.argmax(prediction[0])

# %% [markdown]
# #### Test Example 1

# %%
image_dir = '/content/drive/My Drive/TARP PROJECT/Datasets_digits/4'
image_name = '11f9cd65defaad688cb0c0efb4f2b5e00fcfa61d_3.jpg'

print("Predicted Value : " , test_image(image_dir, image_name))
print("Actual Value : " , '4')
# Out:
# Test Image-->
# (28, 28, 3)
# Final test image shape :
# (1, 28, 28, 1)
# Predicted Value :  4
# Actual Value :  4

# %% [markdown]
# #### Test Example 2

# %%
image_dir = '/content/drive/My Drive/TARP PROJECT/Datasets_digits/5'
image_name = '23c7d2ed30476359326e1a624be570afb98e2699_2.jpg'

print("Predicted Value : " , test_image(image_dir, image_name))
print("Actual Value : " , '5')
# Out:
# Test Image-->
# (28, 28, 3)
# Final test image shape :
# (1, 28, 28, 1)
# Predicted Value :  5
# Actual Value :  5

# %% [markdown]
# #### Test Example 3

# %%
image_dir = '/content/drive/My Drive/TARP PROJECT/Datasets_digits/8'
image_name = '0cfd795fed59753d223f222934728e9a788dd9ba_2.jpg'

print("Predicted Value : " , test_image(image_dir, image_name))
print("Actual Value : " , '8')
# Out:
# Test Image-->
# (28, 28, 3)
# Final test image shape :
# (1, 28, 28, 1)
# Predicted Value :  8
# Actual Value :  8

# %% [markdown]
# #### Test Example 4

# %%
image_dir = '/content/drive/My Drive/TARP PROJECT/Datasets_digits/1'
image_name = '1e563e76027dc5e3582da0669f66ba32653345bd_1.jpg'

print("Predicted Value : " , test_image(image_dir, image_name))
print("Actual Value : " , '1')
# Out:
# Test Image-->
# (28, 28, 3)
# Final test image shape :
# (1, 28, 28, 1)
# Predicted Value :  4
# Actual Value :  1

# %% [markdown]
# So we got 3 out 4 of correct images which is pretty good.

# %% [markdown]
# ## End to End testing of the model

# %%
def show_original_image(image_path):
  img = cv2.imread(image_path)

  plt.imshow(img)
  plt.title('Original Image')

  plt.show()

# %%
def get_image_digits(src_path, filename):
  
  test_sample_file = '/content/drive/My Drive/TARP PROJECT/images_data.csv'
  df_images = pd.read_csv('/content/drive/My Drive/TARP PROJECT/images_data.csv')

  image_test = df_images.loc[df_images['image'] == file_name]

  labels = [image_test.cadran_1, image_test.cadran_2, image_test.cadran_3, image_test.cadran_4]
  cutter = cutDigits(src_file_name=src_path, labels=labels)

  cutter.get_bounding_box_dummy()
  ax, fig = plt.subplots(2,2)
  for i in range(4):
    kernel = np.ones((5, 5), np.uint8)
    dilated = cv2.dilate(cutter.boxes[i], kernel, iterations = 1)
    eroded = cv2.erode(dilated, kernel, iterations = 1)
    dst = cv2.morphologyEx(eroded, cv2.MORPH_CLOSE, kernel)
    blur = cv2.medianBlur(dst, 3)


    plt.subplot(2,2,i+1)
    plt.imshow(blur)
    cutter.boxes[i] = blur

  plt.suptitle('Digits extracted')
  plt.show()

  return cutter.boxes

# %%
def test_digits(digit):

  resized_image = cv2.resize(digit,(28,28))
  mg = cv2.cvtColor(resized_image,cv2.COLOR_BGR2GRAY)
  inverted_image = np.invert(mg)
  inverted_image = inverted_image/255
  inverted_image = inverted_image.astype('float64')

  plt.imshow(inverted_image)
  curr_shape = inverted_image.shape
  img_test = inverted_image.reshape((-1,curr_shape[0], curr_shape[1], 1))
  
  prediction = model.predict(img_test)
  return np.argmax(prediction[0]), mg

# %%
test_sample_folder = '/content/drive/My Drive/TARP PROJECT/Test Samples/Dataset_Frames/'

for i in os.listdir(test_sample_folder)[0:5]:
  print(test_sample_folder + i)
# Out:
# /content/drive/My Drive/TARP PROJECT/Test Samples/Dataset_Frames/017aaf5f05f9cb27557ba2b10121fdd7b910a406.jpg
# /content/drive/My Drive/TARP PROJECT/Test Samples/Dataset_Frames/17bf0739bf830b20ef259d18788e74d4209d922b.jpg
# /content/drive/My Drive/TARP PROJECT/Test Samples/Dataset_Frames/16ddf64847f3343c0b741858e8f499cf13e8efbf.jpg
# /content/drive/My Drive/TARP PROJECT/Test Samples/Dataset_Frames/16c0acbf55777702a5490a805d18d8fd60d01da7.jpg
# /content/drive/My Drive/TARP PROJECT/Test Samples/Dataset_Frames/1c9aa921313f8b3b8dfde6130c91d9de4391570b.jpg

# %% [markdown]
# #### Test Example 1

# %%
image_path = '/content/drive/My Drive/TARP PROJECT/Test Samples/Dataset_Frames/1c9408957a827a1bce36d9057d8a075e7c0b706f.jpg'
filename = '1c9408957a827a1bce36d9057d8a075e7c0b706f.jpg'

show_original_image(image_path)
digits = get_image_digits(image_path, filename)

fig, ax = plt.subplots(3)  
  
preds1, pred_img = test_digits(digits[1])
ax[0].imshow(pred_img)
ax[0].set_title("Predicted Value : " + str(preds1))

preds2, pred_img = test_digits(digits[2])
ax[1].imshow(pred_img)
ax[1].set_title("Predicted Value : " + str(preds2))

preds3, pred_img = test_digits(digits[3])
ax[2].imshow(pred_img)
ax[2].set_title("Predicted Value : " + str(preds3))

fig.tight_layout()

plt.show()

# %% [markdown]
# #### Test Example 2

# %%
image_path = '/content/drive/My Drive/TARP PROJECT/Test Samples/Dataset_Frames/17bf0739bf830b20ef259d18788e74d4209d922b.jpg'
filename = '17bf0739bf830b20ef259d18788e74d4209d922b.jpg'

show_original_image(image_path)
digits = get_image_digits(image_path, filename)

fig, ax = plt.subplots(3)  
  
preds1, pred_img = test_digits(digits[1])
ax[0].imshow(pred_img)
ax[0].set_title("Predicted Value : " + str(preds1))

preds2, pred_img = test_digits(digits[2])
ax[1].imshow(pred_img)
ax[1].set_title("Predicted Value : " + str(preds2))

preds3, pred_img = test_digits(digits[3])
ax[2].imshow(pred_img)
ax[2].set_title("Predicted Value : " + str(preds3))

fig.tight_layout()

plt.show()

# %% [markdown]
# #### Test Example 3

# %%
image_path = '/content/drive/My Drive/TARP PROJECT/Test Samples/Dataset_Frames/16ddf64847f3343c0b741858e8f499cf13e8efbf.jpg'
filename = '16ddf64847f3343c0b741858e8f499cf13e8efbf.jpg'

show_original_image(image_path)
digits = get_image_digits(image_path, filename)

fig, ax = plt.subplots(3)  
  
preds1, pred_img = test_digits(digits[1])
ax[0].imshow(pred_img)
ax[0].set_title("Predicted Value : " + str(preds1))

preds2, pred_img = test_digits(digits[2])
ax[1].imshow(pred_img)
ax[1].set_title("Predicted Value : " + str(preds2))

preds3, pred_img = test_digits(digits[3])
ax[2].imshow(pred_img)
ax[2].set_title("Predicted Value : " + str(preds3))

fig.tight_layout()

plt.show()

# %% [markdown]
# #### Test Example 4

# %%
image_path = '/content/drive/My Drive/TARP PROJECT/Test Samples/Dataset_Frames/017aaf5f05f9cb27557ba2b10121fdd7b910a406.jpg'
filename = '017aaf5f05f9cb27557ba2b10121fdd7b910a406.jpg'

show_original_image(image_path)
digits = get_image_digits(image_path, filename)

fig, ax = plt.subplots(3)  
  
preds1, pred_img = test_digits(digits[1])
ax[0].imshow(pred_img)
ax[0].set_title("Predicted Value : " + str(preds1))

preds2, pred_img = test_digits(digits[2])
ax[1].imshow(pred_img)
ax[1].set_title("Predicted Value : " + str(preds2))

preds3, pred_img = test_digits(digits[3])
ax[2].imshow(pred_img)
ax[2].set_title("Predicted Value : " + str(preds3))

fig.tight_layout()

plt.show()

# %% [markdown]
# #### Test Example 5

# %%
image_path = '/content/drive/My Drive/TARP PROJECT/Test Samples/Dataset_Frames/1c9aa921313f8b3b8dfde6130c91d9de4391570b.jpg'
filename = '1c9aa921313f8b3b8dfde6130c91d9de4391570b.jpg'

show_original_image(image_path)
digits = get_image_digits(image_path, filename)

fig, ax = plt.subplots(3)  

preds1, pred_img = test_digits(digits[1])
ax[0].imshow(pred_img)
ax[0].set_title("Predicted Value : " + str(preds1))

preds2, pred_img = test_digits(digits[2])
ax[1].imshow(pred_img)
ax[1].set_title("Predicted Value : " + str(preds2))

preds3, pred_img = test_digits(digits[3])
ax[2].imshow(pred_img)
ax[2].set_title("Predicted Value : " + str(preds3))

fig.tight_layout()

plt.show()

# %% [markdown]
# ### Final testing with real life example

# %%
def show_frame_image(img):
  plt.imshow(img)
  plt.title('processed frame image')

# %% [markdown]
# #### The complete OCR procedure

# %%
# %%timeit
import sys
sys.path.append('/content/drive/My Drive/TARP PROJECT')

from util import frameExtractor


dataset_dir = '/content/drive/My Drive/TARP PROJECT/Datasets/HQ_digital/'
dest_dir = '/content/drive/My Drive/TARP PROJECT/'
raw_image = '4a322d88fca63d74fb42eee30846e99735c17905.jpg'

show_original_image(dataset_dir + raw_image)

f = frameExtractor(image=None,
                        src_file_name=dataset_dir + raw_image,
                        dst_file_name = dest_dir + raw_image,
                        return_image=True,
                        output_shape=(400, 100))

frame_image = f.extractAndSaveFrame()

show_frame_image(frame_image)

digits = get_image_digits(dest_dir + raw_image, raw_image)

fig, ax = plt.subplots(3)  
  
preds1, pred_img = test_digits(digits[1])
ax[0].imshow(pred_img)
ax[0].set_title("Predicted Value : " + str(preds1))

preds2, pred_img = test_digits(digits[2])
ax[1].imshow(pred_img)
ax[1].set_title("Predicted Value : " + str(preds2))

preds3, pred_img = test_digits(digits[3])
ax[2].imshow(pred_img)
ax[2].set_title("Predicted Value : " + str(preds3))

fig.tight_layout()

plt.show()
# Out:
# 1 loop, best of 3: 1.44 s per loop
